# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id     budget    revenue  \
# 1566  tt0372183   75000000  288500217
# 758   tt1568911   66000000  177584879
# 869   tt0121765  120000000  649398328
# 583   tt0132245   94000000   54744738
# 894   tt0233469   85000000   78382433
#
#                                     original_title  \
# 1566                          The Bourne Supremacy
# 758                                      War Horse
# 869   Star Wars: Episode II - Attack of the Clones
# 583                                         Driven
# 894                              Collateral Damage
#
#                                                    cast          director  \
# 1566  Matt Damon|Franka Potente|Brian Cox|Julia Stil...   Paul Greengrass
# 758   Tom Hiddleston|Benedict Cumberbatch|Toby Kebbe...  Steven Spielberg
# 869   Ewan McGregor|Natalie Portman|Hayden Christens...      George Lucas
# 583   Kip Pardue|Robert Sean Leonard|Til Schweiger|E...      Renny Harlin
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# ...

# %%
data.describe(include = ['object'])
# Out:
#           imdb_id  original_title  \
# count        1889            1889
# unique       1889            1887
# top     tt0497465  Fantastic Four
# freq            1               2
#
#                                                      cast           director  \
# count                                                1889               1889
# unique                                               1878                957
# top     Jennifer Lawrence|Josh Hutcherson|Liam Hemswor...  Steven Soderbergh
# freq                                                    3                 13
#
#                                 tagline  \
# count                              1889
# unique                             1880
# top     Based on the Best Selling Novel
# freq                                  2
#
#                                                  overview  genres  \
# count                                                1889    1889
# ...

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %%
#to calculate and analyze based on profit, we create column'profit', profit = revenue - budget 
data['profit'] = data['revenue'] - data['budget']
data.sample(3)
# Out:
#         imdb_id    budget   revenue original_title  \
# 1362  tt0419706  60000000  55987321           Doom
# 1863  tt0219653  28000000  33000337   Dracula 2000
# 595   tt0186589  11000000  13276953  Sugar & Spice
#
#                                                    cast            director  \
# 1362  Dwayne Johnson|Karl Urban|Rosamund Pike|Ben Da...  Andrzej Bartkowiak
# 1863  Gerard Butler|Christopher Plummer|Jonny Lee Mi...     Patrick Lussier
# 595   Marla Sokoloff|Marley Shelton|Melissa George|M...  Francine McDougall
#
#                                                 tagline  \
# 1362                             No one gets out alive.
# 1863  The Most Seductive Evil of All Time Has Now Be...
# 595   Why would the most popular girl in school wear...
#
#                                                overview  runtime  \
# 1362  A team of space marines known as the Rapid Res...      100
# 1863  In the millenium version of this classic Gothi...       99
# ...

# %%
#for task 21 convert release_date in datetime format:
data['release_date'] = pd.to_datetime(data['release_date'], infer_datetime_format=True)
data.sample(3)
# Out:
#         imdb_id    budget    revenue       original_title  \
# 887   tt0280590  50000000  171269535            Mr. Deeds
# 1876  tt0144964  25000000   15843608  Highlander: Endgame
# 174   tt2004420  18000000  268157400            Neighbors
#
#                                                    cast             director  \
# 887   Adam Sandler|Winona Ryder|John Turturro|Allen ...         Steven Brill
# 1876  Christopher Lambert|Bruce Payne|Adrian Paul|Do...  Douglas Aarniokoski
# 174   Seth Rogen|Zac Efron|Rose Byrne|Dave Franco|Ik...     Nicholas Stoller
#
#                                                 tagline  \
# 887                Small town kid, big time right hook.
# 1876  It will take two immortals to defeat the ultim...
# 174                                     Family vs. Frat
#
#                                                overview  runtime  \
# 887   When Longfellow Deeds, a small-town pizzeria o...       96
# ...

# %%
#for task 23 make a separate column with release_month
data['release_month'] = data['release_date'].dt.month
data.sample(3)
# Out:
#         imdb_id     budget    revenue  \
# 1650  tt0377062   45000000   21009180
# 792   tt0448694  130000000  554987477
# 1318  tt0121766  113000000  850000000
#
#                                     original_title  \
# 1650                         Flight of the Phoenix
# 792                                  Puss in Boots
# 1318  Star Wars: Episode III - Revenge of the Sith
#
#                                                    cast      director  \
# 1650  Dennis Quaid|Tyrese Gibson|Giovanni Ribisi|Mir...    John Moore
# 792   Antonio Banderas|Salma Hayek|Zach Galifianakis...  Chris Miller
# 1318  Ewan McGregor|Natalie Portman|Hayden Christens...  George Lucas
#
#                                                 tagline  \
# 1650                  Out of the ashes, hope will rise.
# 792   Live for danger. Fight for justice. Pray for m...
# 1318                              The saga is complete.
#
#                                                overview  runtime  \
# ...

# %%
#for task 24 make a column with title lengh:
data['title_count']=data.original_title.apply(lambda x:len(x))
data.sample(3)
# Out:
#         imdb_id     budget    revenue           original_title  \
# 1104  tt0332379   35000000  131282949       The School of Rock
# 1224  tt0481499  135000000  585178928               The Croods
# 698   tt1014775   20000000  149281606  Beverly Hills Chihuahua
#
#                                                    cast  \
# 1104  Jack Black|Joan Cusack|Mike White|Sarah Silver...
# 1224  Nicolas Cage|Emma Stone|Ryan Reynolds|Catherin...
# 698   Drew Barrymore|Piper Perabo|Andy GarcÃ­a|Georg...
#
#                          director  \
# 1104            Richard Linklater
# 1224  Kirk De Micco|Chris Sanders
# 698                  Raja Gosnell
#
#                                              tagline  \
# 1104  He just landed the gig of his life: 5th grade.
# 1224                   Meet the first modern family.
# 698          50% Warrior. 50% Lover. 100% Chihuahua.
#
#                                                overview  runtime  \
# ...

# %%
#for task 25 make a column with title lengh:
data['overview_len']=data.overview.apply(lambda x:len(x))
data.sample(3)
# Out:
#         imdb_id    budget    revenue                   original_title  \
# 282   tt1034032  50000000   40828540                            Gamer
# 732   tt1568346  90000000  232617430  The Girl with the Dragon Tattoo
# 1380  tt0399146  32000000   60740827            A History of Violence
#
#                                                    cast  \
# 282   Gerard Butler|Michael C. Hall|Logan Lerman|Amb...
# 732   Daniel Craig|Rooney Mara|Christopher Plummer|G...
# 1380  Viggo Mortensen|Maria Bello|Heidi Hayes|Ashton...
#
#                          director  \
# 282   Mark Neveldine|Brian Taylor
# 732                 David Fincher
# 1380             David Cronenberg
#
#                                                 tagline  \
# 282   In the near future, you don't live to play... ...
# 732                   Evil shall with evil be expelled.
# 1380  Tom Stall had the perfect life... until he bec...
#
#                                                overview  runtime  \
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = 'Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:

data[(data.budget == data.budget.max())]['original_title']
# Out:
# 723    Pirates of the Caribbean: On Stranger Tides
# Name: original_title, dtype: object

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# data.budget.max()
data.loc[data.budget == data.budget.max()]
s = data.loc[data.budget == data.budget.max()]

s[['original_title']+ ['imdb_id']]
# Out:
#                                   original_title    imdb_id
# 723  Pirates of the Caribbean: On Stranger Tides  tt1298650

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = 'Gods and Generals (tt0279111)'

# %%
data[(data.runtime == data.runtime.max())]['original_title']
# Out:
# 1157    Gods and Generals
# Name: original_title, dtype: object

# %%
data.loc[data.runtime == data.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = 'Winnie the Pooh (tt1449283)'

# %%
data[(data.runtime == data.runtime.min())]['original_title']
# Out:
# 768    Winnie the Pooh
# Name: original_title, dtype: object

# %%
data.loc[data.runtime == data.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '110'

# %%
round(data.runtime.mean())
# Out:
# 110

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107'

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале

# %%
answers['6'] = 'Avatar (tt0499549)'

# %%
data[(data.profit == data.profit.max())]['original_title']
# Out:
# 239    Avatar
# Name: original_title, dtype: object

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = 'The Lone Ranger (tt1210819)'

# %%
data[(data.profit == data.profit.min())]['original_title']
# Out:
# 1245    The Lone Ranger
# Name: original_title, dtype: object

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1478'

# %%
data[(data.profit > 0)]['original_title'].count()
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = 'The Dark Knight (tt0468569)'

# %%
#if by 'кассовым' we mean revenue = max:

t = data.loc[data['release_year'] == 2008]
t[t.revenue == t.revenue.max()]['original_title']
# Out:
# 599    The Dark Knight
# Name: original_title, dtype: object

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = 'The Lone Ranger (tt1210819)'

# %%
#if by 'самый убыточный' we mean profit = min:

s = data.loc[(data['release_year'] == 2012) | 
             (data['release_year'] == 2013) |
             (data['release_year'] == 2014)]
s[s.profit == s.profit.min()]['original_title']
# Out:
# 1245    The Lone Ranger
# Name: original_title, dtype: object

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

# %%
answers['11'] = 'Drama'

# %%
data.describe(include=['object'])
# Out:
#           imdb_id  original_title  \
# count        1889            1889
# unique       1889            1887
# top     tt0497465  Fantastic Four
# freq            1               2
#
#                                                      cast           director  \
# count                                                1889               1889
# unique                                               1878                957
# top     Jennifer Lawrence|Josh Hutcherson|Liam Hemswor...  Steven Soderbergh
# freq                                                    3                 13
#
#                                 tagline  \
# count                              1889
# unique                             1880
# top     Based on the Best Selling Novel
# freq                                  2
#
#                                                  overview  genres  \
# count                                                1889    1889
# ...

# %%
data.genres.describe()
# Out:
# count       1889
# unique       652
# top       Comedy
# freq         141
# Name: genres, dtype: object

# %%
Counter(data.genres.str.split('|').sum()).most_common(1)
# Out:
# [('Drama', 782)]

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = 'Drama'

# %%
p = data.loc[data.profit > 0]
p
# Out:
#         imdb_id     budget     revenue                original_title  \
# 0     tt0369610  150000000  1513528810                Jurassic World
# 1     tt1392190  150000000   378436354            Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                     Insurgent
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                     Furious 7
# ...         ...        ...         ...                           ...
# 1871  tt0171433   30000000    37036004             Keeping the Faith
# 1875  tt0219854   65000000    69700000                       The Kid
# 1877  tt0199725   20000000    27728118             Love & Basketball
# 1883  tt0122459   24000000    36609995                  Return to Me
# 1884  tt0120903   75000000   157299717                         X-Men
#
#                                                    cast  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# ...

# %%
Counter(p.genres.str.split('|').sum()).most_common()
# Out:
# [('Drama', 560),
#  ('Comedy', 551),
#  ('Thriller', 446),
#  ('Action', 444),
#  ('Adventure', 337),
#  ('Romance', 242),
#  ('Crime', 231),
#  ('Family', 226),
#  ('Science Fiction', 195),
#  ('Fantasy', 188),
#  ('Horror', 150),
#  ('Animation', 120),
#  ('Mystery', 119),
#  ('Music', 47),
#  ('History', 46),
#  ('War', 41),
#  ('Western', 12),
#  ('Documentary', 7)]

# %%
Counter(p.genres.str.split('|').sum()).most_common(1)
# Out:
# [('Drama', 560)]

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = 'Peter Jackson'

# %%
t = data.groupby('director')['revenue'].agg(['sum']).sort_values('sum', ascending = False)
t
# Out:
#                           sum
# director
# Peter Jackson      6490593685
# Christopher Nolan  4167548502
# David Yates        4154295625
# Michael Bay        3886938960
# J.J. Abrams        3579169916
# ...                       ...
# David MichÃ´d         2295423
# Steven Shainberg      2281089
# Paul Schrader         2062066
# Keanu Reeves          2054941
# Simon Hunter          2033165
#
# [957 rows x 1 columns]

# %%
t.iloc[0]
# Out:
# sum    6490593685
# Name: Peter Jackson, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = 'Robert Rodriguez'

# %%
action_movies = data[data.genres.str.contains('Action', na=False)]
action_movies
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# 6     tt1340138  155000000   440603537                    Terminator Genisys
# ...         ...        ...         ...                                   ...
# 1877  tt0199725   20000000    27728118                     Love & Basketball
# 1880  tt0190374   35000000    15185241                    Dungeons & Dragons
# 1882  tt0217756   24000000    12372410                       Ready to Rumble
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
#
# ...

# %%
Counter(action_movies.director.str.split('|').sum()).most_common()
# Out:
# [('Robert Rodriguez', 9),
#  ('Michael Bay', 7),
#  ('Paul W.S. Anderson', 7),
#  ('Antoine Fuqua', 6),
#  ('Ridley Scott', 6),
#  ('Brett Ratner', 5),
#  ('Quentin Tarantino', 5),
#  ('Zack Snyder', 5),
#  ('Roland Emmerich', 5),
#  ('Andrzej Bartkowiak', 5),
#  ('Louis Leterrier', 5),
#  ('Tony Scott', 5),
#  ('Paul Greengrass', 5),
#  ('Peter Jackson', 5),
#  ('Lee Tamahori', 5),
#  ('Gore Verbinski', 5),
#  ('Rob Cohen', 5),
#  ('Peter Berg', 5),
#  ('J.J. Abrams', 4),
#  ('Lana Wachowski', 4),
#  ('Lilly Wachowski', 4),
#  ('Olivier Megaton', 4),
#  ('Guy Ritchie', 4),
#  ('Bryan Singer', 4),
#  ('Tim Story', 4),
#  ('Renny Harlin', 4),
#  ('Mark Neveldine', 4),
#  ('Brian Taylor', 4),
#  ('Dominic Sena', 4),
#  ('Justin Lin', 4),
#  ('Christopher Nolan', 4),
#  ('Simon West', 4),
#  ('John Moore', 4),
#  ('Steven Spielberg', 4),
#  ('Martin Campbell', 4),
#  ('John Singleton', 4),
#  ('Len Wiseman', 4),
#  ('Brad Bird', 3),
#  ('Matthew Vaughn', 3),
#  ('Neill Blomkamp', 3),
# ...

# %%
Counter(action_movies.director.str.split('|').sum()).most_common(1)
# Out:
# [('Robert Rodriguez', 9)]

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = 'Chris Hemsworth'

# %%
year_2012 = data.loc[data['release_year'] == 2012][['cast', 'revenue']]
year_2012.groupby('cast')['revenue'].agg(['sum']).sort_values('sum', ascending = False)
# Out:
#                                                            sum
# cast
# Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chri...  1519557910
# Daniel Craig|Judi Dench|Javier Bardem|Ralph Fie...  1108561013
# Christian Bale|Michael Caine|Gary Oldman|Anne H...  1081041287
# Ian McKellen|Martin Freeman|Richard Armitage|An...  1017003568
# John Leguizamo|Ray Romano|Chris Wedge|Denis Lea...   877244782
# ...                                                        ...
# Kirsten Dunst|Jim Sturgess|Timothy Spall|James ...     8106475
# Robert Pattinson|Sarah Gadon|Juliette Binoche|P...     6063556
# Bruce Willis|Josh Duhamel|Rosario Dawson|Vincen...     4636169
# Jason Bateman|Hope Davis|Frank Grillo|Paula Pat...     3428048
# Nicolas Cage|Malin Ã…kerman|Josh Lucas|Sami Gay...     2106557
#
# [111 rows x 1 columns]

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = 'Matt Damon'

# %%
high_budget_movies = data.loc[data['budget'] > data.budget.mean()]
Counter(high_budget_movies.cast.str.split('|').sum()).most_common()
# Out:
# [('Matt Damon', 18),
#  ('Adam Sandler', 17),
#  ('Angelina Jolie', 16),
#  ('Tom Cruise', 15),
#  ('Samuel L. Jackson', 15),
#  ('Eddie Murphy', 15),
#  ('Mark Wahlberg', 14),
#  ('Hugh Jackman', 14),
#  ('Ben Stiller', 14),
#  ('Jamie Foxx', 14),
#  ('Russell Crowe', 14),
#  ('Johnny Depp', 13),
#  ('Jude Law', 13),
#  ('Bruce Willis', 13),
#  ('Will Smith', 13),
#  ('Dwayne Johnson', 12),
#  ('Ian McKellen', 12),
#  ('Brad Pitt', 12),
#  ('Owen Wilson', 12),
#  ('Cameron Diaz', 12),
#  ('Nicolas Cage', 12),
#  ('Robert De Niro', 12),
#  ('Leonardo DiCaprio', 11),
#  ('Daniel Craig', 11),
#  ('Robert Downey Jr.', 11),
#  ('Steve Buscemi', 11),
#  ('Vin Diesel', 10),
#  ('Mark Ruffalo', 10),
#  ('Jack Black', 10),
#  ('Denzel Washington', 10),
#  ('Emma Watson', 10),
#  ('Gary Oldman', 10),
#  ('Tom Hanks', 10),
#  ('Orlando Bloom', 10),
#  ('Ralph Fiennes', 9),
#  ('Cate Blanchett', 9),
#  ('Michael Caine', 9),
#  ('Ewan McGregor', 9),
#  ('Paul Bettany', 9),
# ...

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = 'Action'

# %%
NCage_movies = data[data.cast.str.contains('Nicolas Cage', na=False)]

Counter(NCage_movies.genres.str.split('|').sum()).most_common(1)
# Out:
# [('Action', 17)]

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = 'K-19: The Widowmaker (tt0267626)'

# %%
PP_movies = data[data.production_companies.str.contains('Paramount Pictures', na=False)]
PP_movies[PP_movies.profit == PP_movies.profit.min()]['original_title']
# Out:
# 925    K-19: The Widowmaker
# Name: original_title, dtype: object

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '2015'

# %%
t = data.groupby(['release_year'])['revenue'].agg(['sum']).sort_values('sum', ascending = False)
t.iloc[0]
# Out:
# sum    25449202382
# Name: 2015, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '2014'

# %%
WB_data = data[data.production_companies.str.contains('Warner Bros', na=False)]
w = WB_data.groupby(['release_year'])['profit'].agg(['sum']).sort_values('sum', ascending = False)
w.iloc[0]
# Out:
# sum    2295464519
# Name: 2014, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = 'Сентябрь'

# %%
#first convert release_date into datetime format => see data preparation part above

# %%
data.release_date.dt.month.value_counts()
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: release_date, dtype: int64

# %%
t = data.release_date.dt.month.value_counts()
t.index[0]
# Out:
# 9

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '450'

# %%
t = data.release_date.dt.month.value_counts()

t[6]+t[7]+t[8]
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = 'Peter Jackson'

# %%
#first prepare separate column 'release_month' for months => see data preparation part above

# %%
winter_data = data[data.release_month.isin(['1', '2', '12'])]
Counter(winter_data.director.str.split('|').sum()).most_common(1)
# Out:
# [('Peter Jackson', 7)]

# %%
#var2:
winter_data.director.value_counts().sort_values(ascending=False).head(10)
# Out:
# Peter Jackson        7
# Clint Eastwood       6
# Steven Soderbergh    6
# Adam Shankman        4
# Martin Scorsese      4
# Nancy Meyers         4
# Shawn Levy           4
# Steven Spielberg     3
# Rob Marshall         3
# Marc Lawrence        3
# Name: director, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = 'Four By Two Productions'

# %%
#first prepare separate column 'title_count' for title length => see data preparation part above

# %%
 data.groupby('production_companies')['title_count'].agg(['mean']).sort_values('mean', ascending = False)
# Out:
#                                                     mean
# production_companies
# Twentieth Century Fox Film Corporation|Four By ...  83.0
# Walt Disney|Walden Media                            62.0
# Walt Disney Pictures|21 Laps Entertainment|Jim ...  59.0
# Plan B Entertainment|Virtual Studios|Scott Free...  58.0
# Dune Entertainment|Fox 2000 Pictures|Walden Media   56.0
# ...                                                  ...
# FilmNation Entertainment|Everest Entertainment       3.0
# Ixtlan Productions|Emperor Motion Pictures|Glob...   2.0
# Columbia Pictures|Relativity Media                   2.0
# Twentieth Century Fox Film Corporation|Donners'...   2.0
# Focus Films|Starz Animation|Relativity Media|Ti...   1.0
#
# [1624 rows x 1 columns]

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = 'Midnight Picture Show'

# %%
#first prepare separate column 'overview_len' for title length => see data preparation part above

# %%
data.groupby('production_companies')['overview_len'].agg(['mean']).sort_values('mean', ascending = False)
# Out:
#                                                       mean
# production_companies
# Lions Gate Films|Lakeshore Entertainment|Greene...  1000.0
# Fox Searchlight Pictures|Room 9 Entertainment        964.0
# Columbia Pictures|Revolution Studios|Happy Madi...   959.0
# Mandalay Pictures|TriStar Pictures|Brookwell-Mc...   936.0
# Lions Gate Family Entertainment|Relativity Medi...   909.0
# ...                                                    ...
# Focus Films                                           72.0
# Columbia Pictures Corporation|Apatow Productions      64.0
# Cheyenne Enterprises|Epsilon Motion Pictures|Em...    62.0
# Motion Picture Corporation of America|Artisan E...    59.0
# Paramount Pictures|Plan B Entertainment|Regency...    58.0
#
# [1624 rows x 1 columns]

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = 'Inside Out, The Dark Knight, 12 Years a Slave'

# %%
data_small = pd.DataFrame(data, columns=['original_title', 'vote_average'])

data_small.sort_values(['vote_average'], ascending = False).head(10)
# Out:
#                                      original_title  vote_average
# 599                                 The Dark Knight           8.1
# 118                                    Interstellar           8.0
# 125                              The Imitation Game           8.0
# 9                                        Inside Out           8.0
# 34                                             Room           8.0
# 1183                        The Wolf of Wall Street           7.9
# 128                                       Gone Girl           7.9
# 1191                               12 Years a Slave           7.9
# 119                         Guardians of the Galaxy           7.9
# 1081  The Lord of the Rings: The Return of the King           7.9

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27'] = 'na'

# %%
#не сделала. intertool combinations мы не проходили - решение, предложенное в slack не осилила :(

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': 'Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': 'Gods and Generals (tt0279111)',
#  '3': 'Winnie the Pooh (tt1449283)',
#  '5': '107',
#  '6': 'Avatar (tt0499549)',
#  '7': 'The Lone Ranger (tt1210819)',
#  '8': '1478',
#  '9': 'The Dark Knight (tt0468569)',
#  '10': 'The Lone Ranger (tt1210819)',
#  '11': 'Drama',
#  '12': 'Drama',
#  '13': 'Peter Jackson',
#  '14': 'Robert Rodriguez',
#  '15': 'Chris Hemsworth',
#  '16': 'Matt Damon',
#  '17': 'Action',
#  '18': 'K-19: The Widowmaker (tt0267626)',
#  '19': '2015',
#  '20': '2014',
#  '21': 'Сентябрь',
#  '22': '450',
#  '23': 'Peter Jackson',
#  '24': 'Four By Two Productions',
#  '25': 'Midnight Picture Show',
#  '26': 'Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': 'na',
#  '4': '110'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
